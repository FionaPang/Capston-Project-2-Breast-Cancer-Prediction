# %% [markdown]
# # Capstone Two - Breast Cancer Prediction - Data Wrangling
# Table of content
# 1. Data explotation
# 2. Check and drop missing value/duplicated value
# 3. Handle text data for future analysis
# 4. Distribution of Data
# 5. Save Data
# 6. Summary

# %%
#Data Loading
import pandas as pd
import numpy as py
import seaborn as sn
import matplotlib.pyplot as plt
from library.sb_utils import save_file
data=pd.read_csv('../Raw_Data/data.csv')

# %% [markdown]
# ## 1. Data exploration

# %% [markdown]
# Source of data: https://www.kaggle.com/uciml/breast-cancer-wisconsin-data
#
# Attribute Information from data source:
#
# 1) ID number
# 2) Diagnosis (M = malignant, B = benign)
#
# Ten real-valued features are computed for each cell nucleus:
#
# a) radius (mean of distances from center to points on the perimeter)
# b) texture (standard deviation of gray-scale values)
# c) perimeter
# d) area
# e) smoothness (local variation in radius lengths)
# f) compactness (perimeter^2 / area - 1.0)
# g) concavity (severity of concave portions of the contour)
# h) concave points (number of concave portions of the contour)
# i) symmetry
# j) fractal dimension ("coastline approximation" - 1)
#
# The mean, standard error and "worst" or largest (mean of the three
# largest values) of these features were computed for each image,
# resulting in 30 features. For instance, field 3 is Mean Radius, field
# 13 is Radius SE, field 23 is Worst Radius.

# %%
data.info
# Out:
# <bound method DataFrame.info of            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
data.describe().T
# Out:
#                          count          mean           std          min  \
# id                       569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean              569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean             569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean           569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean          569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean         569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean           569.0  8.879932e-02  7.971981e-02     0.000000
# concave points_mean      569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean            569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension_mean   569.0  6.279761e-02  7.060363e-03     0.049960
# radius_se                569.0  4.051721e-01  2.773127e-01     0.111500
# ...

# %%
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
#Note - total 569 rows, 33 columns
data.shape
# Out:
# (569, 33)

# %%
data.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
# note: Diagnosis column - The diagnosis of breast tissues (M = malignant (positive), B = benign (negative))

# %% [markdown]
# ## 2. Check and drop missing value/duplicated value

# %%
# Note - noly the column 'Unnamed: 32' has missing values
data.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
# drop the "Unnamed: 32" column
data.drop(['Unnamed: 32'],axis=1, inplace=True)
data.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
print("There is " + str(data['id'].isnull().sum()) + " missing value in id column.")
# Out:
# There is 0 missing value in id column.

# %%
# Note: it shows there is no duplicated id in the dataset
duplicated_id=data[data.duplicated('id', keep=False)].sort_values(by='id')
print(duplicated_id)
# Out:
# Empty DataFrame
# Columns: [id, diagnosis, radius_mean, texture_mean, perimeter_mean, area_mean, smoothness_mean, compactness_mean, concavity_mean, concave points_mean, symmetry_mean, fractal_dimension_mean, radius_se, texture_se, perimeter_se, area_se, smoothness_se, compactness_se, concavity_se, concave points_se, symmetry_se, fractal_dimension_se, radius_worst, texture_worst, perimeter_worst, area_worst, smoothness_worst, compactness_worst, concavity_worst, concave points_worst, symmetry_worst, fractal_dimension_worst]
# Index: []
#
# [0 rows x 32 columns]

# %%
# Since the id column is not necessary for analysis here, the id column can be dropped
data.drop(['id'], axis=1, inplace=True)
data.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
# check if each feature is unique identifier
feature=data.columns
print(feature.is_unique)
# Out:
# True

# %% [markdown]
# ## 3. Handle text data for future analysis

# %%
# Update the data from column 'diagnosis' 
# digit 1 represent M(Malignant/positive), digit 0 represent B(Benign/negative)
data['diagnosis']=data['diagnosis'].replace({'M':1})
data['diagnosis']=data['diagnosis'].replace({'B':0})

# %%
data['diagnosis']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int64

# %% [markdown]
# ## 4. Distribution of data

# %%
# Since there is no missing value or duplicated value for id, there are total 569 patient records.
# 357 cases are diagnosised as Bnign(negative), and 212 are diagnosised as Malignant(positive)
data['diagnosis'].value_counts().plot(kind='bar')
plt.xlabel('diagnosis (0=Benign, 1=Malignant)')
plt.ylabel('Number of cases')
# Out:
# Text(0, 0.5, 'Number of cases')

# %%
total_case=data.diagnosis.count()
positive_case = data[data['diagnosis'] == 1].diagnosis.count()
negative_case=data[data['diagnosis'] == 0].diagnosis.count()
positive_perc = (positive_case/total_case)*100
negative_perc = (negative_case/total_case)*100
print("There are " + str(total_case) + " cases." + " "+str(positive_case) + " cases are Malignant, and " + str(negative_case) + " cases are Benign.")
print(str(round(positive_perc))+ "% is malignant, " + str(round(negative_perc)) + "% is benign.")
# Out:
# There are 569 cases. 212 cases are Malignant, and 357 cases are Benign.
# 37% is malignant, 63% is benign.

# %%
data['diagnosis'].value_counts().plot(kind='pie', autopct='%1.1f%%', labels=['Benign', 'Malignant'])
# Out:
# <AxesSubplot:ylabel='diagnosis'>

# %%
data.dtypes
# Out:
# diagnosis                    int64
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# ...

# %%
data.hist(figsize=(15,10))
plt.subplots_adjust(hspace=0.5);

# %%
# Find the correlation between Features, some are strongly correlated to diagnosis result.
# such as "texture_mean", "fractal_dimension_mean", "texture_se", "smoothness_se", "symmetry_se"...etc.
plt.figure(figsize=(10, 10))
sn.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
data.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# ## 5. Save data as new csv file

# %%
# save the data to a new csv file
datapath = '../data'
save_file(data, 'data_cleaned.csv', datapath)
# Out:
# A file already exists with this name.
#
# Do you want to overwrite? (Y/N)Y
# Writing file.  "../data/data_cleaned.csv"

# %% [markdown]
# ## 6. Summary

# %% [markdown]
# * The dataset was downloaded from Kaggle (https://www.kaggle.com/uciml/breast-cancer-wisconsin-data)
#
#
# * The purpose for this object is pre-process the raw data for the purpose of developing a machine learning model to classify the breast tumor to benign or malignant based on numeric features from FNA images.
#
#
# * There are 569 rows and 33 columns in the dataset. The 33th column, "Unamed: 32" was dropped since the whole columns are missing data. The remiaining 32 columns are unique identifier. All data from the rest of 32 columns has no missing values. The column 'id' is dropped as it is not necessary for the analysis.
#
#
# * The diagnosis column is text data, which used "M" to represent Malignant, and used "B" to represent Benign. For future analysis, theh diagnosis column is replaced with integer, which used "1" to represent Malignant, and used "0" to represent Benign. There are total 569 cases, 62.7% is Bengine (357 cases) while 37.3% is Malignant (212 cases). A bar chart and pie chart is used to visualy represent the distribution of diagnosis result of the data set. A series of bar chart is used to represent the ditribution of data for each feature.
#
#
# * From the correlation heatmap, some features are strongly correlated to digagnosis result, such as "texture_mean", "fractal_dimension_mean", "texture_se", "smoothness_se", "symmetry_se"...etc. Further EDA and analysis will be needed to confirm the correlation between features and diagnosis for the cancer prediction.
